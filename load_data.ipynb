# %% [markdown]
# # Utilidades de carga de datos JSON

# %%
"""Utilidades para cargar datos JSON desde `data/raw`.

Este módulo ofrece funciones para:
- Listar todos los archivos `.json` existentes en un directorio.
- Cargar el contenido de esos `.json` en memoria.
"""

from __future__ import annotations

import json
from pathlib import Path
from typing import Any, Dict, List, Union


def listar_archivos_json(directorio: str | Path = "data/raw", recursivo: bool = False) -> List[Path]:
    """Devuelve la lista de archivos `.json` en el directorio dado.

    Args:
        directorio: Ruta del directorio a inspeccionar.
        recursivo: Si es True, busca también en subdirectorios.

    Returns:
        Lista de rutas (`Path`) a archivos `.json`.
    """
    base = Path(directorio)
    if not base.exists() or not base.is_dir():
        raise FileNotFoundError(f"No se encontró el directorio: {base}")

    patron = "**/*.json" if recursivo else "*.json"
    return [p for p in sorted(base.glob(patron)) if p.is_file()]


def cargar_todos_los_json(rutas: List[str | Path], estricto: bool = True) -> List[Any]:
    """Carga todos los archivos `.json` de un conjunto de rutas.

    Lee cada archivo `.json` provisto en `rutas` y devuelve una lista con
    el contenido parseado de cada uno, en el mismo orden de entrada.

    Args:
        rutas: Lista o conjunto de rutas a archivos `.json`.
        estricto: Si True, lanza excepción ante JSON inválido; de lo
                  contrario, ignora archivos con errores y continúa.

    Returns:
        Lista con el contenido JSON de cada archivo.

    Nota:
        No se devuelve un `set` porque los objetos JSON (dict/list) no son
        hashables. Si necesitas eliminar duplicados, puedes convertir cada
        elemento a cadena con `json.dumps(..., sort_keys=True)` y operar allí.
    """
    resultados: List[Any] = []
    for r in rutas:
        ruta = Path(r)
        if not ruta.exists() or not ruta.is_file():
            raise FileNotFoundError(f"No existe el archivo: {ruta}")
        if ruta.suffix.lower() != ".json":
            continue
        try:
            with ruta.open("r", encoding="utf-8") as f:
                datos = json.load(f)
            resultados.append(datos)
        except json.JSONDecodeError as e:
            if estricto:
                raise ValueError(f"JSON inválido en {ruta}: {e}") from e
            # En modo no estricto, omitimos archivos con error
    return resultados


def extrae_html(
    datos_json: Any,
    clave: str = "html",
    omitir_vacios: bool = True,
) -> List[Dict[str, Any]]:
    """Extrae solo el campo HTML de una estructura JSON agrupada por archivo.

    Acepta estructuras como:
        { "archivo.json": [ {"url":..., "html":..., ...}, ... ] }
    y devuelve:
        [ {"html": ...}, {"html": ...}, ... ]

    También funciona si `datos_json` es una lista (o lista de listas) de
    registros tipo dict. Recorre recursivamente y extrae cualquier dict que
    contenga la clave indicada.

    Args:
        datos_json: Estructura con registros que incluyen la clave de HTML.
        clave: Nombre de la clave a extraer (por defecto "html").
        omitir_vacios: Si True, omite valores vacíos o None.

    Returns:
        Lista de diccionarios con solo la clave de HTML.
    """
    resultados: List[Dict[str, Any]] = []

    def visitar(nodo: Any) -> None:
        if isinstance(nodo, dict):
            if clave in nodo:
                valor = nodo.get(clave)
                if not (
                    omitir_vacios
                    and (
                        valor is None
                        or (isinstance(valor, str) and valor.strip() == "")
                    )
                ):
                    resultados.append({clave: valor})
            for v in nodo.values():
                visitar(v)
        elif isinstance(nodo, list):
            for elem in nodo:
                visitar(elem)
        # otros tipos se ignoran

    visitar(datos_json)
    return resultados




def _marker_variants(m: str) -> List[str]:
    """Genera variantes del marcador con y sin escapes de comillas.

    Incluye:
    - El marcador tal cual.
    - Versión con `\"` reemplazado por `"`.
    - Versión con `"` reemplazado por `\"`.
    - Versión sin espacios extremos.
    """
    return list({
        m,
        m.strip(),
        m.replace(r'\"', '"'),
        m.replace('"', r'\"'),
    })


def extrae_texto_json_entre(
    file_json: str | Path,
    inicio: str = '"items":[',
    fin: str = '],"totalPages"',
) -> str:
    """Extrae el texto entre dos marcadores dentro de un archivo JSON.

    Lee el archivo como texto y devuelve el substring comprendido entre la
    primera ocurrencia de `inicio` y la siguiente ocurrencia de `fin`.

    Por compatibilidad, intenta variantes con comillas escapadas (\\") si
    no encuentra coincidencia exacta.

    Args:
        file_json: Ruta al archivo `.json` a leer.
        inicio: Marcador inicial. Por defecto busca '"items":['.
        fin: Marcador final. Por defecto busca '],"totalPages"'.

    Returns:
        El texto encontrado entre `inicio` y `fin`. Si no se encuentran
        los marcadores en ninguna variante, devuelve cadena vacía.
    """
    ruta = Path(file_json)
    if not ruta.exists() or not ruta.is_file():
        raise FileNotFoundError(f"No existe el archivo: {ruta}")

    contenido = ruta.read_text(encoding="utf-8", errors="ignore")

    inicio_real: str | None = None
    for variante in _marker_variants(inicio):
        idx = contenido.find(variante)
        if idx != -1:
            inicio_real = variante
            inicio_idx = idx + len(variante)
            break

    if inicio_real is None:
        return ""

    fin_real: str | None = None
    for variante in _marker_variants(fin):
        fin_idx = contenido.find(variante, inicio_idx)
        if fin_idx != -1:
            fin_real = variante
            break

    if fin_real is None:
        return ""

    return contenido[inicio_idx:fin_idx]


def main() -> None:
    """Ejecución ad-hoc: carga JSON por rutas y extrae `items`."""
    try:
        archivos = listar_archivos_json("data/raw", recursivo=False)
    except FileNotFoundError as e:
        print(e)
        return

    print(f"Encontrados {len(archivos)} archivo(s) .json en data/raw")
    contenidos = cargar_todos_los_json(archivos, estricto=False)
    print(f"Cargados {len(contenidos)} archivo(s) JSON")


if __name__ == "__main__":
    main()

# %%
# Redefinición: extrae_texto_json_entre para trabajar sobre contenido_html
def extrae_texto_json_entre(
    contenido_html: Any,
    ini_text: str ='"items":[{"bodyTypeId":',
    fin_text: str = '}],"totalPages"'
) -> List[str]:
    """Extrae, para cada HTML, el bloque entre `inicio` y `fin` y reconstruye \"items\": [...].

    Entrada admitida: lista de dicts con clave 'html', lista de strings o string único.
    Del marcador final elimina ,\"totalPages\" (o su versión escapada) para formar "items": [...].
    """
    textos: List[str] = []
    if isinstance(contenido_html, str):
        textos = [contenido_html]
    elif isinstance(contenido_html, list):
        for elem in contenido_html:
            if isinstance(elem, dict) and 'html' in elem and isinstance(elem['html'], str):
                textos.append(elem['html'])
            elif isinstance(elem, str):
                textos.append(elem)
            elif isinstance(elem, list):
                for sub in elem:
                    if isinstance(sub, dict) and 'html' in sub and isinstance(sub['html'], str):
                        textos.append(sub['html'])
                    elif isinstance(sub, str):
                        textos.append(sub)
    elif isinstance(contenido_html, dict) and 'html' in contenido_html and isinstance(contenido_html['html'], str):
        textos = [contenido_html['html']]

    resultados: List[str] = []
    for contenido in textos:
        contenido = contenido.replace("\\", "")  
        ini = contenido.find(ini_text)
        if ini == -1:
            return ""
        ini += len(ini_text)
        fin = contenido.find(fin_text, ini)
        if fin == -1:
            return ""
        cuerpo = contenido[ini:fin]
        fin_text= fin_text.replace(',\"totalPages\"', '')
        fragmento = f"{ini_text}{cuerpo}{fin_text}"
        resultados.append(fragmento)
    return resultados

# %%
def extraer_entre(texto,
                 ini_text: str ='"items":[{"bodyTypeId":',
                 fin_text: str = '}],"totalPages"',
                ):
    """Devuelve el texto entre ini_text y fin_text. Si no se encuentra, devuelve una cadena vacía."""
    ini = texto.find(ini_text)
    if ini == -1:
        return ""
    ini += len(ini_text)
    fin = texto.find(fin_text, ini)
    if fin == -1:
        return ""
    cuerpo = texto[ini:fin]
    fin_text= fin_text.replace(',\"totalPages\"', '')
    fragmento = f"{ini_text}{cuerpo}{fin_text}"

    return fragmento

# %%
archivos = listar_archivos_json("data/raw", recursivo=False)
contenidos = cargar_todos_los_json(archivos, estricto=False)
contenido_html = extrae_html(contenidos)
extrae_items = extrae_texto_json_entre(contenido_html)

# %%
extrae_items
# Out:
# ['"items":[{"bodyTypeId":14,"creationDate":"2025-08-26T09:57:53Z","hp":110,"fuelType":"Gasolina","fuelTypeId":2,"hasWarranty":true,"id":"8762366","img":"https://a.mcdn.es/mnet/2025/08/26/8762366/32372272_g.jpg","imgUrl":"https://a.mcdn.es/mnet/2025/08/26/8762366/32372272_g.jpg/359x269cut/","isCertified":false,"isFinanced":false,"isUrgent":false,"isProfessional":true,"isUrlSemantic":true,"km":8000,"location":{"provinceIds":[20],"regionId":18,"regionLiteral":"Pau00EDs Vasco","mainProvince":"Guipu00FAzcoa","mainProvinceId":20,"cityId":20903,"cityLiteral":"Astigarraga"},"make":"BMW","makeId":7,"modelId":5326,"pack":{"legacyId":18,"type":"start"},"price":9995,"url":"/ocasion/bmw/r_ninet/scrambler-2018-en-guipuzcoa-8762366.htm","offerType":{"id":0,"literal":"Ocasiu00F3n"},"phone":"943470919","photos":["https://a.mcdn.es/mnet/2025/08/26/8762366/32372272_g.jpg","https://a.mcdn.es/mnet/2025/08/26/8762366/32372273_g.jpg","https://a.mcdn.es/mnet/2025/08/26/8762366/32372274_g.jpg","https://a.mcdn.es/mnet/2025/08/26/8762366/32372275_g.jpg","https://a.mcdn.es/mnet/2025/08/26/8762366/32372276_g.jpg","https://a.mcdn.es/mnet/2025/08/26/8762366/32372277_g.jpg","https://a.mcdn.es/mnet/2025/08/26/8762366/32372278_g.jpg","https://a.mcdn.es/mnet/2025/08/26/8762366/32372279_g.jpg","https://a.mcdn.es/mnet/2025/08/26/8762366/32372280_g.jpg"],"provinceId":20,"publicationDate":"2025-08-26T09:57:53Z","specificFuelTypeId":2,"title":"BMW R nineT Scrambler","videos":[],"warrantyText":"1 au00F1o","year":2018,"seller":{"name":"dasMoto","isProfessional":true,"contractId":"888887","pack":{"legacyId":18,"type":"start"}}},{"creationDate":"2025-08-23T09:27:59Z","fuelType":"Gasolina","fuelTypeId":2,"hasWarranty":false,"id":"8760435","img":"https://a.mcdn.es/mnet/2025/08/23/8760435/32358302_g.jpg","imgUrl":"https://a.mcdn.es/mnet/2025/08/23/8760435/32358302_g.jpg/359x269cut/","isCertified":false,"isFinanced":false,"isUrgent":false,"isProfessional":false,"isUrlSemantic":true,"km":12960,"location":{"provinceIds":[28],"regionId":14,"regionLiteral":"Madrid","mainProvince":"Madrid","mainProvinceId":28,"cityId":28181,"cityLiteral":"Villaviciosa de Odu00F3n"},"make":"BMW","makeId":7,"modelId":5326,"price":11990,"url":"/ocasion/bmw/r_ninet//5-2019-en-madrid-8760435.htm","offerType":{"id":0,"literal":"Ocasiu00F3n"},"phone":"667431076","photos":["https://a.mcdn.es/mnet/2025/08/23/8760435/32358302_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760435/32358300_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760435/32358301_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760435/32361020_g.jpg"],"provinceId":28,"publicationDate":"2025-08-23T10:41:07Z","specificFuelTypeId":2,"title":"BMW R nineT /5","videos":[],"year":2019},{"creationDate":"2025-08-23T00:40:26Z","fuelType":"Gasolina","fuelTypeId":2,"hasWarranty":false,"id":"8760378","img":"https://a.mcdn.es/mnet/2025/08/23/8760378/32356808_g.jpg","imgUrl":"https://a.mcdn.es/mnet/2025/08/23/8760378/32356808_g.jpg/359x269cut/","isCertified":false,"isFinanced":false,"isUrgent":false,"isProfessional":false,"isUrlSemantic":true,"km":22500,"location":{"provinceIds":[30],"regionId":16,"regionLiteral":"Murcia","mainProvince":"Murcia","mainProvinceId":30,"cityId":30030,"cityLiteral":"Murcia"},"make":"BMW","makeId":7,"modelId":5326,"price":9500,"url":"/ocasion/bmw/r_ninet/2014-en-murcia-8760378.htm","offerType":{"id":0,"literal":"Ocasiu00F3n"},"phone":"697694321","photos":["https://a.mcdn.es/mnet/2025/08/23/8760378/32356808_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760378/32356809_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760378/32356810_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760378/32356811_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760378/32356812_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760378/32356814_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760378/32356815_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760378/32356816_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760378/32356817_g.jpg","https://a.mcdn.es/mnet/2025/08/23/8760378/32356821_g.jpg"]," ...
#  '"items":[{"bodyTypeId":14,"creationDate":"2025-07-28T13:31:10Z","hp":110,"fuelType":"Gasolina","fuelTypeId":2,"hasWarranty":false,"id":"8740885","isCertified":false,"isFinanced":false,"isUrgent":false,"isProfessional":false,"isUrlSemantic":true,"km":32000,"location":{"provinceIds":[8],"regionId":9,"regionLiteral":"Catalunya","mainProvince":"Barcelona","mainProvinceId":8},"make":"BMW","makeId":7,"modelId":5326,"price":9900,"url":"/ocasion/bmw/r_ninet/urban_gs-2018-en-barcelona-8740885.htm","offerType":{"id":0,"literal":"Ocasiu00F3n"},"phone":"662266815","provinceId":8,"publicationDate":"2025-07-28T13:59:54Z","specificFuelTypeId":2,"title":"BMW R nineT Urban GS","videos":[],"year":2018},{"bodyTypeId":14,"creationDate":"2025-07-21T16:10:16Z","hp":110,"fuelType":"Gasolina","fuelTypeId":2,"hasWarranty":false,"id":"8735315","isCertified":false,"isFinanced":false,"isUrgent":false,"isProfessional":false,"isUrlSemantic":true,"km":6000,"location":{"provinceIds":[29],"regionId":1,"regionLiteral":"Andalucu00EDa","mainProvince":"Mu00E1laga","mainProvinceId":29},"make":"BMW","makeId":7,"modelId":5326,"price":18000,"url":"/ocasion/bmw/r_ninet/pure-2023-en-malaga-8735315.htm","offerType":{"id":0,"literal":"Ocasiu00F3n"},"phone":"647389131","provinceId":29,"publicationDate":"2025-07-21T17:32:17Z","specificFuelTypeId":2,"title":"BMW R nineT Pure","videos":[],"year":2023},{"bodyTypeId":14,"creationDate":"2025-07-14T13:31:36Z","hp":110,"fuelType":"Gasolina","fuelTypeId":2,"hasWarranty":false,"id":"8728790","isCertified":false,"isFinanced":false,"isUrgent":false,"isProfessional":false,"isUrlSemantic":true,"km":7200,"location":{"provinceIds":[15],"regionId":12,"regionLiteral":"Galicia","mainProvince":"A Coruu00F1a","mainProvinceId":15},"make":"BMW","makeId":7,"modelId":5326,"price":9999,"url":"/ocasion/bmw/r_ninet/scrambler-2016-en-a_coruna-8728790.htm","offerType":{"id":0,"literal":"Ocasiu00F3n"},"phone":"667436206","provinceId":15,"publicationDate":"2025-07-14T13:48:37Z","specificFuelTypeId":2,"title":"BMW R nineT Scrambler","videos":[],"year":2016},{"bodyTypeId":14,"creationDate":"2025-07-10T21:07:42Z","hp":110,"fuelType":"Gasolina","fuelTypeId":2,"hasWarranty":false,"id":"8726505","isCertified":false,"isFinanced":false,"isUrgent":false,"isProfessional":false,"isUrlSemantic":true,"km":8100,"location":{"provinceIds":[33],"regionId":3,"regionLiteral":"Asturias","mainProvince":"Asturias","mainProvinceId":33},"make":"BMW","makeId":7,"modelId":5326,"price":10000,"url":"/ocasion/bmw/r_ninet/scrambler-2018-en-asturias-8726505.htm","offerType":{"id":0,"literal":"Ocasiu00F3n"},"phone":"629889002","provinceId":33,"publicationDate":"2025-07-10T22:33:50Z","specificFuelTypeId":2,"title":"BMW R nineT Scrambler","videos":[],"year":2018}]']

# %%
import json
from typing import List, Union

BASE_URL = "https://motos.coches.net/"

def _find_json_array_after_items(s: str) -> str:
    key = '"items":['
    start = s.find(key)
    if start == -1:
        return ""
    i = start + len(key) - 1
    depth = 0
    arr_start = None
    for pos in range(i, len(s)):
        ch = s[pos]
        if ch == '[':
            if depth == 0:
                arr_start = pos
            depth += 1
        elif ch == ']':
            depth -= 1
            if depth == 0 and arr_start is not None:
                return s[arr_start:pos+1]
    return ""

def _normalize_url(url: str) -> str:
    if not url:
        return url
    u = url.strip()
    if u.startswith("http://") or u.startswith("https://"):
        return u
    # Evita doble barra al unir
    if u.startswith("/"):
        u = u[1:]
    return BASE_URL + u

def extra_parse_item(extrae_items: Union[str, List[str]], extrac_list: List[str] = None) -> List[dict]:
    if extrac_list is None:
        extrac_list = ['km', 'precio', 'year']

    norm_map = {
        'km': 'km',
        'precio': 'price',
        'price': 'price',
        'year': 'year',
        'año': 'year',
        'anio': 'year',
        'url': 'url',
    }
    wanted = [norm_map.get(f.lower(), f) for f in extrac_list]

    chunks = [extrae_items] if isinstance(extrae_items, str) else list(extrae_items)
    resultados = []

    for chunk in chunks:
        if not isinstance(chunk, str):
            continue
        arr_text = _find_json_array_after_items(chunk)
        if not arr_text:
            continue

        try:
            items = json.loads(arr_text)
            if not isinstance(items, list):
                continue
        except json.JSONDecodeError:
            continue

        for obj in items:
            if not isinstance(obj, dict):
                continue
            row = {}

            # siempre útil añadir id si está
            if 'id' in obj:
                row['id'] = obj.get('id')

            # añade url siempre que exista, normalizada
            if 'url' in obj:
                row['url'] = _normalize_url(obj.get('url'))

            for f in wanted:
                val = obj.get(f, None)

                if f == 'url':
                    row['url'] = _normalize_url(val)
                    continue

                if isinstance(val, str) and f in ('km', 'price', 'year'):
                    num = ''.join(ch for ch in val if ch.isdigit())
                    val = int(num) if num else None

                row[f] = val

            resultados.append(row)

    return resultados

# %%
res = extra_parse_item(extrae_items, extrac_list=['title','km', 'price', 'year','url','imgUrl','mainProvince'])

# %%
res
# Out:
# [{'id': '8762366',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/scrambler-2018-en-guipuzcoa-8762366.htm',
#   'title': 'BMW R nineT Scrambler',
#   'km': 8000,
#   'price': 9995,
#   'year': 2018,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/08/26/8762366/32372272_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8760435',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet//5-2019-en-madrid-8760435.htm',
#   'title': 'BMW R nineT /5',
#   'km': 12960,
#   'price': 11990,
#   'year': 2019,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/08/23/8760435/32358302_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8760378',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/2014-en-murcia-8760378.htm',
#   'title': 'BMW R nineT',
#   'km': 22500,
#   'price': 9500,
#   'year': 2014,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/08/23/8760378/32356808_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8759793',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/2014-en-madrid-8759793.htm',
#   'title': 'BMW R nineT',
#   'km': 9500,
#   'price': 10500,
#   'year': 2014,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/08/22/8759793/32351506_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8759386',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/2017-en-baleares-8759386.htm',
#   'title': 'BMW R nineT',
#   'km': 20000,
#   'price': 8500,
#   'year': 2017,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/08/21/8759386/32348905_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8644153',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/2022-en-madrid-8644153.htm',
#   'title': 'BMW R nineT',
#   'km': 22000,
#   'price': 10000,
#   'year': 2022,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/04/07/8644153/31301234_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8756139',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/2015-en-vizcaya-8756139.htm',
#   'title': 'BMW R nineT',
#   'km': 10500,
#   'price': 9999,
#   'year': 2015,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/08/17/8756139/32338157_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8751211',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet//5-2021-en-baleares-8751211.htm',
#   'title': 'BMW R nineT /5',
#   'km': 3900,
#   'price': 13500,
#   'year': 2021,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/08/09/8751211/32280537_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8741932',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet//5-2021-en-badajoz-8741932.htm',
#   'title': 'BMW R nineT /5',
#   'km': 17000,
#   'price': 11800,
#   'year': 2021,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/07/29/8741932/32195935_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8741972',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/2023-en--8741972.htm',
#   'title': 'BMW R nineT',
#   'km': 13000,
#   'price': 15000,
#   'year': 2023,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/07/29/8741972/32197971_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8741220',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/scrambler-2017-en-madrid-8741220.htm',
#   'title': 'BMW R nineT Scrambler',
#   'km': 29000,
#   'price': 9500,
#   'year': 2017,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/07/28/8741220/32189584_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8673656',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet//5-2020-en-las_palmas-8673656.htm',
#   'title': 'BMW R nineT /5',
#   'km': 15500,
#   'price': 10950,
#   'year': 2020,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/05/14/8673656/31547274_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8736958',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet//5-2019-en-barcelona-8736958.htm',
#   'title': 'BMW R nineT /5',
#   'km': 8500,
#   'price': 13800,
#   'year': 2019,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/07/23/8736958/32153810_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8722313',
#   'url': 'https://motos.coches.net/ocasion/r_ninet/2018-en-cantabria-8722313.htm',
#   'title': 'R nineT',
#   'km': 34000,
#   'price': 9200,
#   'year': 2018,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/07/07/8722313/32013656_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8719659',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/2014-en-lleida-8719659.htm',
#   'title': 'BMW R nineT',
#   'km': 33800,
#   'price': 9295,
#   'year': 2014,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/07/03/8719659/31992018_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8600734',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/2023-en-cadiz-8600734.htm',
#   'title': 'BMW R nineT',
#   'km': 7500,
#   'price': 19500,
#   'year': 2023,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/02/17/8600734/32320703_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8718860',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/urban_gs-2021-en--8718860.htm',
#   'title': 'BMW R nineT Urban GS',
#   'km': 16000,
#   'price': 12000,
#   'year': 2021,
#   'imgUrl': 'https://a.mcdn.es/mnet/2025/07/02/8718860/31983814_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8320009',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/scrambler-2020-en-madrid-8320009.htm',
#   'title': 'BMW R nineT Scrambler',
#   'km': 7284,
#   'price': 12800,
#   'year': 2020,
#   'imgUrl': 'https://a.mcdn.es/mnet/2024/04/07/8320009/27309227_g.jpg/359x269cut/',
#   'mainProvince': None},
#  {'id': '8779327',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/scrambler-2017-en-madrid-8779327.htm',
#   'title': 'BMW R nineT Scrambler',
#   'km': 40000,
#   'price': 10200,
#   'year': 2017,
#   'imgUrl': None,
#   'mainProvince': None},
#  {'id': '8752780',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/urban_gs-2023-en-valencia-8752780.htm',
#   'title': 'BMW R nineT Urban GS',
#   'km': 2200,
#   'price': 15000,
#   'year': 2023,
#   'imgUrl': None,
#   'mainProvince': None},
#  {'id': '8740885',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/urban_gs-2018-en-barcelona-8740885.htm',
#   'title': 'BMW R nineT Urban GS',
#   'km': 32000,
#   'price': 9900,
#   'year': 2018,
#   'imgUrl': None,
#   'mainProvince': None},
#  {'id': '8735315',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/pure-2023-en-malaga-8735315.htm',
#   'title': 'BMW R nineT Pure',
#   'km': 6000,
#   'price': 18000,
#   'year': 2023,
#   'imgUrl': None,
#   'mainProvince': None},
#  {'id': '8728790',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/scrambler-2016-en-a_coruna-8728790.htm',
#   'title': 'BMW R nineT Scrambler',
#   'km': 7200,
#   'price': 9999,
#   'year': 2016,
#   'imgUrl': None,
#   'mainProvince': None},
#  {'id': '8726505',
#   'url': 'https://motos.coches.net/ocasion/bmw/r_ninet/scrambler-2018-en-asturias-8726505.htm',
#   'title': 'BMW R nineT Scrambler',
#   'km': 8100,
#   'price': 10000,
#   'year': 2018,
#   'imgUrl': None,
#   'mainProvince': None}]

# %%
 {\"bodyTypeId\":14,
\"creationDate\":\"2025-01-22T12:56:21Z\",
\"hp\":110,
\"fuelType\":\"Gasolina\",
\"fuelTypeId\":2,
\"hasWarranty\":true,
\"id\":\"8576019\",
\"img\":\"https://a.mcdn.es/mnet/2025/01/22/8576019/30562965_g.jpg\",
\"imgUrl\":\"https://a.mcdn.es/mnet/2025/01/22/8576019/30562965_g.jpg/359x269cut/\",
\"isCertified\":false,
\"isFinanced\":true,
\"isUrgent\":false,
\"isProfessional\":true,
\"isUrlSemantic\":true,
\"km\":15000,
\"location\":{\"provinceIds\":[24],
\"regionId\":7,
\"regionLiteral\":\"Castilla y Le\u00F3n\",
\"mainProvince\":\"Le\u00F3n\",
\"mainProvinceId\":24,
\"cityId\":24142,
\"cityLiteral\":\"San Andr\u00E9s del Rabanedo\"},
\"make\":\"BMW\",\"makeId\":7,\"modelId\":5326,
\"pack\":{\"legacyId\":21,
\"type\":\"advance\"},
\"price\":10500,
\"url\":\"/ocasion/bmw/r_ninet/scrambler-2016-en-leon-8576019.htm\",
\"offerType\":{\"id\":0,
\"literal\":\"Ocasi\u00F3n\"},
\"phone\":\"987981024\",
\"provinceId\":24,
\"publicationDate\":\"2025-10-19T11:33:53Z\",
\"specificFuelTypeId\":2,
\"title\":\"BMW R nineT Scrambler\",
\"videos\":[],
\"warrantyText\":\"1 A\u00D1O\",
\"year\":2016,
\"seller\":{\"name\":\"Bmw Bernesga Motor \",
\"isProfessional\":true,
\"contractId\":\"1001564\",
\"pack\":{\"legacyId\":21,
\"type\":\"advance\"}}},
